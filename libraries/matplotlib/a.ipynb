# %%
#pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= [1,2,3,4,5]
y= [4,6,8,6,3]
y2= [10,6,0,7,4]
plt.plot(x,y, color="red", linestyle = "--", marker= ">", markersize=25)
plt.plot(x,y2, color="blue", linestyle = "--" , marker= ">", markersize=25)
plt.title("line chart")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
#bar chart
x=["A", "B", "c", "D"]
y=[10, 15, 7, 12]
plt.bar(x,y, color="gold")
plt.show()

# %%
#horizontal bar chart
x=["A", "B", "c", "D"]
y=[10, 15, 7, 12]
plt.barh(x,y, color="orange")
plt.show()

# %%
x=["python", "java", "c++", "js" ,"react" , "go"]
y=[14, 25,20, 15,17,19]
plt.pie(y, labels=x, autopct='%1.11f%%', startangle=180 )
plt.show()

# %%
data= np.random.randn(100)
plt.hist(data, bins=30, color='orange')
plt.show()

# %%
x= [1,2,3,4,5]
y=[5,7,9,3,5]
plt.scatter(x, y, color='r', s=100, marker="*")
plt.savefig("sactter.png")
plt.show()
